# %%
#matplotlib
from matplotlib import pyplot as plt
import numpy as np
x = [0,2,4,6,8]
y = [1,3,5,7,9]

plt.plot(x,y,'g+')

# %%
plt.bar(x,y)
# Out:
# <BarContainer object of 5 artists>

# %%
z = [2,4,5,6,6,9,8]
plt.hist(z)
# Out:
# (array([1., 0., 1., 0., 1., 2., 0., 0., 1., 1.]),
#  array([2. , 2.7, 3.4, 4.1, 4.8, 5.5, 6.2, 6.9, 7.6, 8.3, 9. ]),
#  <BarContainer object of 10 artists>)

# %%
x = np.linspace(0, 1.5 * np.pi, 100)
x
# Out:
# array([0.        , 0.04759989, 0.09519978, 0.14279967, 0.19039955,
#        0.23799944, 0.28559933, 0.33319922, 0.38079911, 0.428399  ,
#        0.47599889, 0.52359878, 0.57119866, 0.61879855, 0.66639844,
#        0.71399833, 0.76159822, 0.80919811, 0.856798  , 0.90439789,
#        0.95199777, 0.99959766, 1.04719755, 1.09479744, 1.14239733,
#        1.18999722, 1.23759711, 1.28519699, 1.33279688, 1.38039677,
#        1.42799666, 1.47559655, 1.52319644, 1.57079633, 1.61839622,
#        1.6659961 , 1.71359599, 1.76119588, 1.80879577, 1.85639566,
#        1.90399555, 1.95159544, 1.99919533, 2.04679521, 2.0943951 ,
#        2.14199499, 2.18959488, 2.23719477, 2.28479466, 2.33239455,
#        2.37999443, 2.42759432, 2.47519421, 2.5227941 , 2.57039399,
#        2.61799388, 2.66559377, 2.71319366, 2.76079354, 2.80839343,
#        2.85599332, 2.90359321, 2.9511931 , 2.99879299, 3.04639288,
#        3.09399276, 3.14159265, 3.18919254, 3.23679243, 3.28439232,
#        3.33199221, 3.3795921 , 3.42719199, 3.47479187, 3.52239176,
#        3.56999165, 3.61759154, 3.66519143, 3.71279132, 3.76039121,
#        3.8079911 , 3.85559098, 3.90319087, 3.95079076, 3.99839065,
#        4.04599054, 4.09359043, 4.14119032, 4.1887902 , 4.23639009,
#        4.28398998, 4.33158987, 4.37918976, 4.42678965, 4.47438954,
#        4.52198943, 4.56958931, 4.6171892 , 4.66478909, 4.71238898])

# %%
import numpy as np
import matplotlib.pyplot as plt
  
# First create some toy data:
x = np.linspace(0, 1.5 * np.pi, 100)
y = np.sin(x**2)+np.cos(x**2)
  
fig, axs = plt.subplots(2, 2,
                        subplot_kw = dict(polar = True))
axs[0, 0].plot(x, y)
axs[1, 1].scatter(x, y)
  
fig.suptitle('matplotlib.pyplot.subplots() Example')
plt.show()

# %%
#Subplots
from matplotlib import pyplot as plt
plt.subplots()
# Out:
# (<Figure size 432x288 with 1 Axes>, <AxesSubplot:>)

# %%
fig, ax = plt.subplots()

# %%
ax
# Out:
# <AxesSubplot:>

# %%
import matplotlib.image as img

# %%
x = img
type(x)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-54-840f8b52ad7a> in <module>
# ----> 1 x = img()
#       2 type(x)
#
# TypeError: 'module' object is not callable
