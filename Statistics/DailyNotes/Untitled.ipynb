# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x_rand = np.random.rand(100,1)
plt.hist(x_rand)
plt.show()

# %%
x_randn = np.random.randn(100,1)
plt.hist(x_randn)
plt.show()

# %%
x_randint = np.random.randint(1,100,1)
plt.hist(x_randn)
plt.show()
