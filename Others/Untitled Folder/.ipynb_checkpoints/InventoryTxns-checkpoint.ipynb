# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
inv_data = pd.read_csv(r"C:\Users\j1013189\Downloads\InventoryTransaction_AME_AP_EP_20201022.csv")

# %%
inv_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 647316 entries, 0 to 647315
# Data columns (total 53 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   week_id                    647316 non-null  object
#  1   start_date                 647316 non-null  object
#  2   location                   647316 non-null  int64
#  3   brand                      647316 non-null  object
#  4   base_currency              647316 non-null  object
#  5   sku_id                     647316 non-null  int64
#  6   ttl_sales_qty              647316 non-null  float64
#  7   ttl_sales_cost             647316 non-null  float64
#  8   ttl_sales_value_exvat      647316 non-null  float64
#  9   ttl_sales_value_incvat     647316 non-null  float64
#  10  ttl_sales_qty_lc           647316 non-null  float64
#  11  ttl_sales_cost_lc          647316 non-null  float64
#  12  ttl_sales_value_exvat_lc   647316 non-null  float64
# ...

# %%
sns.boxplot(inv_data['ttl_sales_qty'])
# Out:
# C:\Users\j1013189\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='ttl_sales_qty'>

# %%
inv_data[inv_data['ttl_sales_qty'] > 200]
# Out:
#         week_id start_date   location brand base_currency     sku_id  \
# 280353  W202040  9/25/2020  309140002   AME           KWD  128784903
# 531570  W202042  10/9/2020  309140002   AME           KWD  128784903
# 546123  W202040  9/25/2020  309140002   AME           KWD  128798902
# 612760  W202040  9/25/2020  309140002   AME           KWD  128770527
# 618115  W202042  10/9/2020  300830002   AME           KWD  128776102
# 645912  W202041  10/2/2020  309140002   AME           KWD  128784903
#
#         ttl_sales_qty  ttl_sales_cost  ttl_sales_value_exvat  \
# 280353          484.0        538.3007               1091.629
# 531570          238.0        264.7016                538.298
# 546123          265.0        294.5716                602.477
# 612760          290.0        323.1523                671.527
# 618115          383.0        812.6220                  0.071
# 645912          283.0        314.7502                678.176
#
# ...

# %%
sns.boxplot(inv_data['fp_sales_qty'])
# Out:
# C:\Users\j1013189\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='fp_sales_qty'>

# %%
inv_data[inv_data['fp_sales_qty'] > 200]
# Out:
#         week_id start_date   location brand base_currency     sku_id  \
# 280353  W202040  9/25/2020  309140002   AME           KWD  128784903
# 531570  W202042  10/9/2020  309140002   AME           KWD  128784903
# 546123  W202040  9/25/2020  309140002   AME           KWD  128798902
# 612760  W202040  9/25/2020  309140002   AME           KWD  128770527
# 618115  W202042  10/9/2020  300830002   AME           KWD  128776102
# 645912  W202041  10/2/2020  309140002   AME           KWD  128784903
#
#         ttl_sales_qty  ttl_sales_cost  ttl_sales_value_exvat  \
# 280353          484.0        538.3007               1091.629
# 531570          238.0        264.7016                538.298
# 546123          265.0        294.5716                602.477
# 612760          290.0        323.1523                671.527
# 618115          383.0        812.6220                  0.071
# 645912          283.0        314.7502                678.176
#
# ...

# %%
sns.boxplot(inv_data['md_sales_qty'])
# Out:
# C:\Users\j1013189\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='md_sales_qty'>
