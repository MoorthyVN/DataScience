# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
soh_data = pd.read_csv(r"C:\Users\j1013189\Downloads\InventoryOnHand_AME_AP_EP_20200925_20201022.csv")

# %%
soh_data.head()
# Out:
#    week_id   location brand currency     sku_id uom  soh_qty  soh_cost  \
# 0  W202041  308490002   AME      KWD  128600133  EA      6.0   25.1428
# 1  W202040  300940002   AME      KWD  128640090  EA     10.0   31.8578
# 2  W202042  300660002   AME      KWD  125180207  EA      1.0    3.1952
# 3  W202043  300830002   AME      KWD  128553073  EA      4.0   14.6737
# 4  W202043  300130002   AME      KWD  128904524  EA      4.0    7.6185
#
#    soh_value
# 0     99.469
# 1    140.915
# 2      4.145
# 3     54.927
# 4     36.472

# %%
soh_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2747757 entries, 0 to 2747756
# Data columns (total 9 columns):
#  #   Column     Dtype
# ---  ------     -----
#  0   week_id    object
#  1   location   int64
#  2   brand      object
#  3   currency   object
#  4   sku_id     int64
#  5   uom        object
#  6   soh_qty    float64
#  7   soh_cost   float64
#  8   soh_value  float64
# dtypes: float64(3), int64(2), object(4)
# memory usage: 188.7+ MB

# %%
soh_data[(soh_data['soh_qty'] == 0) & (soh_data['soh_cost'] == 0) & (soh_data['soh_value'] == 0)]
# Out:
# Empty DataFrame
# Columns: [week_id, location, brand, currency, sku_id, uom, soh_qty, soh_cost, soh_value]
# Index: []

# %%
import collections
print('week_id Distinct values: ',collections.Counter(soh_data['week_id']),'\n')
print('location Distinct values: ',collections.Counter(soh_data['location']),'\n')
print('brand Distinct values: ',collections.Counter(soh_data['brand']),'\n')
print('currency Distinct values: ',collections.Counter(soh_data['currency']),'\n')
print('sku_id Distinct values: ',collections.Counter(soh_data['sku_id']),'\n')
print('uom Distinct values: ',collections.Counter(soh_data['uom']),'\n')
# Out:
# week_id Distinct values:  Counter({'W202040': 696121, 'W202041': 690863, 'W202042': 687900, 'W202043': 672873})
#
# ...

# %%
sns.boxplot(soh_data['soh_qty'])
# Out:
# C:\Users\j1013189\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='soh_qty'>

# %%
soh_data[soh_data['soh_qty'] < -10000]
# Out:
#          week_id   location brand currency     sku_id uom  soh_qty  soh_cost  \
# 71400    W202042  309160002   AME      KWD  128858017  EA -37034.0  -42.1402
# 164775   W202042  309140002   AME      KWD  128858017  EA -68048.0 -234.9092
# 241465   W202040  309150002   AME      KWD  128858017  EA -24428.0  -22.3747
# 438069   W202041  309150002   AME      KWD  128858017  EA -25470.0  -23.3292
# 676615   W202043  309140002   AME      KWD  128858017  EA -69983.0 -241.5890
# 688260   W202040  309130002   AME      KWD  128858017  EA -29045.0 -107.7570
# 861113   W202043  309160002   AME      KWD  128858017  EA -39886.0  -45.3855
# 1278727  W202040  309160002   AME      KWD  128858017  EA -31060.0  -35.3425
# 1354598  W202041  309130002   AME      KWD  128858017  EA -30382.0 -112.7170
# 1531066  W202042  309150002   AME      KWD  128858017  EA -26451.0  -24.2278
# 1967511  W202043  309150002   AME      KWD  128858017  EA -27815.0  -25.4771
# ...

# %%
soh_data['currency'].sort_values(ascending=True)[0:1:]
# Out:
# 0    KWD
# Name: currency, dtype: object
